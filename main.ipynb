# %%
import sys
import os

PROJECT_ROOT = os.getcwd()   # current working directory
sys.path.insert(0, PROJECT_ROOT)

print("Project root set to:", PROJECT_ROOT)
# Out:
# Project root set to: c:\ELT\ETL1
